# %% [markdown]
# ## Import Required Libraries

# %%
import os
import re

import numpy as np
import pandas as pd

from PyPDF2 import PdfReader

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Take Resume and Job Description

# %%
resume_path = input(
    "Enter the path of your resume PDF: "
).strip()

job_description = input(
    "Paste the job description here: "
).strip()


if not os.path.exists(resume_path):
    print("Resume file not found!")

else:
    print("\nResume found successfully!")

print("\nJob description received!")
# Out:
# Resume found successfully!
#
# Job description received!

# %% [markdown]
# ## Extract Text from Resume

# %%
reader = PdfReader(resume_path)

resume_text = ""

for page in reader.pages:

    text = page.extract_text()

    if text:
        resume_text += text


print("Resume text extracted successfully!")

print("\nFirst 500 characters:\n")
print(resume_text[:500])
# Out:
# Resume text extracted successfully!
#
# First 500 characters:
#
# DEV VERMA
# B-20, New no-1/1633, Mansarovar Park, North East Delhi, Delhi 110032  |  8882581952  |  devxvrm@gmail.com
# PROFESSIONAL SUMMARY
# Customer-focused  and  responsible  professional  with  strong  communication,  teamwork  and  problem-solving
# abilities. Quick to learn new processes and effective in fast-paced, customer-facing environments. Committed to
# maintaining high standards of service, quality, cleanliness and safety while supporting smooth daily operations and
# building strong supervi
